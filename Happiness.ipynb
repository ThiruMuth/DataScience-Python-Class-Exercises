# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# In C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# ...

# %%
scores=pd.read_csv('datasets_912_1664_scores.csv')
countries = pd.read_csv('datasets_912_1664_countries.csv')
happiness=pd.read_csv('world_happiness_datasets_894_813759_2015.csv')

# %%
scores.describe()
# Out:
#               Year         Rank        Score
# count  3153.000000  3153.000000  3153.000000
# mean   2014.300666    41.869648    39.031082
# std       0.784318    28.851303    31.527650
# min    2013.000000     1.000000     0.000000
# 25%    2014.000000    18.000000    10.000000
# 50%    2015.000000    37.000000    45.000000
# 75%    2015.000000    62.000000    60.000000
# max    2015.000000   118.000000   100.000000

# %%
scores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3153 entries, 0 to 3152
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Country Code      3153 non-null   object
#  1   Country Name      3153 non-null   object
#  2   Year              3153 non-null   int64
#  3   Category          3153 non-null   object
#  4   Rank              3153 non-null   int64
#  5   Score             3153 non-null   int64
#  6   Open Data         3153 non-null   object
#  7   Existent          3153 non-null   object
#  8   Current           3153 non-null   object
#  9   Public            3153 non-null   object
#  10  Free              3153 non-null   object
#  11  Digital           3153 non-null   object
#  12  Online            3153 non-null   object
#  13  Machine Readable  3153 non-null   object
#  14  Downloadable      3153 non-null   object
#  15  Open License      3153 non-null   object
# ...

# %%
countries.loc[countries['Country Name'].str.startswith('A')]
# Out:
#     Country Code         Country Name  2015 Rank  2015 Score  2014 Rank  \
# 5             AU            Australia          5          67        5.0
# 23            AT              Austria         23          50       23.0
# 37            AL              Albania         37          42       98.0
# 54            AR            Argentina         54          34       50.0
# 80            AZ           Azerbaijan         78          25       98.0
# 105           AW                Aruba        106          13       98.0
# 115           AG  Antigua and Barbuda        116           8       98.0
# 116           DZ              Algeria        117           7       98.0
# 144           AM              Armenia        123           0       98.0
#
#      2014 Score  2013 Rank  2013 Score
# 5          72.0        9.0        66.0
# 23         59.0       23.0        51.0
# 37          0.0       61.0         0.0
# 54         42.0       61.0         0.0
# 80          0.0       61.0         0.0
# ...

# %%
countries.describe()
# Out:
#         2015 Rank  2015 Score   2014 Rank  2014 Score   2013 Rank  2013 Score
# count  149.000000  149.000000  133.000000  133.000000  130.000000  130.000000
# mean    71.932886   27.302013   61.984962   31.676692   46.776923   21.846154
# std     39.947375   20.678918   32.534361   24.745844   19.415995   26.418651
# min      1.000000    0.000000    1.000000    0.000000    1.000000    0.000000
# 25%     37.000000   10.000000   34.000000    0.000000   32.000000    0.000000
# 50%     71.000000   27.000000   66.000000   34.000000   61.000000    0.000000
# 75%    112.000000   42.000000   98.000000   51.000000   61.000000   43.000000
# max    123.000000   78.000000   98.000000   97.000000   61.000000   94.000000

# %%
scores2015=scores.loc[scores['Year']==2015]
scores2014=scores.loc[scores['Year']==2014]
scores2013=scores.loc[scores['Year']==2013]

# %%
scores_with_index=scores.set_index(['Year', 'Country Name','Category'])
scores_with_index=scores_with_index.drop(['Country Code','Rank'],axis=1)

# %%
scores_with_index1=scores_with_index.replace(['Yes','No'],[1,0])
scores_with_index1.head()
# Out:
#                                            Score  Open Data Existent Current  \
# Year Country Name Category
# 2015 Albania      Air Pollution               35          0        1       0
#                   Company Registrations       35          0        1       0
#                   Election Results            45          0        1       1
#                   Government Budget           60          0        1       1
#                   Government Expenditures     60          0        1       1
#
#                                           Public Free Digital Online  \
# Year Country Name Category
# 2015 Albania      Air Pollution                1    1       1      1
#                   Company Registrations        1    1       1      1
#                   Election Results             1    1       1      1
#                   Government Budget            1    1       1      1
#                   Government Expenditures      1    1       1      1
#
# ...

# %%
scores_with_index_groupby=scores_with_index.groupby(level=['Year','Country Name']).sum()
pd.set_option('display.max_rows', None)
scores_with_index_groupby.head()
# Out:
#                    Score
# Year Country Name
# 2013 Australia       660
#      Austria         505
#      Bangladesh      335
#      Belgium         265
#      Bermuda         360

# %%
countries.head()
# Out:
#   Country Code    Country Name  2015 Rank  2015 Score  2014 Rank  2014 Score  \
# 0           TW          Taiwan          1          78       11.0        67.0
# 1           GB  United Kingdom          2          76        1.0        97.0
# 2           DK         Denmark          3          70        2.0        83.0
# 3           CO        Colombia          4          68       12.0        66.0
# 4           FI         Finland          5          67        4.0        73.0
#
#    2013 Rank  2013 Score
# 0       36.0        42.0
# 1        1.0        94.0
# 2        2.0        87.0
# 3       61.0         0.0
# 4        7.0        72.0

# %%
countries2015=countries.iloc[:,[1,3]]
countries2015['Year']=2015
countries2015=countries2015.rename(columns={"2015 Score":"Country Score"})
countries2014=countries.iloc[:,[1,5]]
countries2014['Year']=2014
countries2014=countries2014.rename(columns={"2014 Score":"Country Score"})
countries2013=countries.iloc[:,[1,7]]
countries2013['Year']=2013
countries2013=countries2013.rename(columns={"2013 Score":"Country Score"})
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
countries_transpose=countries2013
countries_transpose.head()
# Out:
#      Country Name  Country Score  Year
# 0          Taiwan           42.0  2013
# 1  United Kingdom           94.0  2013
# 2         Denmark           87.0  2013
# 3        Colombia            0.0  2013
# 4         Finland           72.0  2013

# %%
countries_transpose=countries_transpose.append(countries2014,ignore_index=True,verify_integrity=True,sort=False)
countries_transpose=countries_transpose.append(countries2015,ignore_index=True,verify_integrity=True,sort=False)

# %%
countries_transpose.count()
# Out:
# Country Name     149
# Country Score    130
# Year             149
# dtype: int64

# %%
countries_transpose=countries_transpose.set_index(['Year','Country Name'])

# %%
scores_with_index_groupby.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 275 entries, (2013, 'Australia') to (2015, 'Uruguay')
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Score   275 non-null    int64
# dtypes: int64(1)
# memory usage: 4.2+ KB

# %%
countries_transpose_bk=countries_transpose

# %%
countries_transpose=countries_transpose.join(scores_with_index_groupby,on=['Year','Country Name'],how='left')

# %%
countries_transpose.head()
# Out:
#                      Country Score  Score
# Year Country Name
# 2013 Taiwan                   42.0  420.0
#      United Kingdom           94.0  940.0
#      Denmark                  87.0  870.0
#      Colombia                  0.0    NaN
#      Finland                  72.0  715.0

# %%
df=countries_transpose.reset_index()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           149 non-null    int64
#  1   Country Name   149 non-null    object
#  2   Country Score  130 non-null    float64
#  3   Score          60 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 4.8+ KB

# %%
happiness.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
happines_score=happiness.iloc[:,0:4]

# %%
happines_score.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427

# %%
countries_transpose_2015=countries2015
countries_transpose_2015=countries_transpose_2015.set_index(['Year','Country Name'])

# %%
happines_score=happines_score.rename(columns={"Country":"Country Name"})
happines_score.head()
# Out:
#   Country Name          Region  Happiness Rank  Happiness Score
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427

# %%
happines_score=happines_score.set_index(['Country Name'])

# %%
countries_transpose_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 149 entries, (2015, 'Taiwan') to (2015, 'Venezuela, Bolivarian Republic of')
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Score  149 non-null    int64
# dtypes: int64(1)
# memory usage: 2.9+ KB

# %%
happines_score.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 158 entries, Switzerland to Togo
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Region           158 non-null    object
#  1   Happiness Rank   158 non-null    int64
#  2   Happiness Score  158 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 4.9+ KB

# %%
countries_transpose_2015_join=countries_transpose_2015.join(happines_score,on=['Country Name'],how='left')

# %%
countries_transpose_2015_join=countries_transpose_2015_join.reset_index()
countries_transpose_2015_join
countries_transpose_2015_join=countries_transpose_2015_join.set_index(['Year','Region','Country Name'])

# %%
countries_transpose_2015_join.corr(method='pearson')
# Out:
#                  Country Score  Happiness Rank  Happiness Score
# Country Score         1.000000       -0.477254         0.490999
# Happiness Rank       -0.477254        1.000000        -0.991998
# Happiness Score       0.490999       -0.991998         1.000000

# %%
countries_transpose_2015_join.cov()
# Out:
#                  Country Score  Happiness Rank  Happiness Score
# Country Score       427.617631     -473.949732        12.316925
# Happiness Rank     -473.949732     2107.060409       -52.799132
# Happiness Score      12.316925      -52.799132         1.344482

# %%
sns.lmplot(x='Country Score', y='Happiness Score',data=countries_transpose_2015_join,height=8,aspect=2,fit_reg=True)

# %%
countries_transpose_2015_groupby_region=countries_transpose_2015_join.groupby(level=['Year','Region']).mean()

# %%
sns.lmplot(x='Country Score', y='Happiness Score',data=countries_transpose_2015_groupby_region,height=8,aspect=2,fit_reg=True)

# %%
countries_transpose_2015_groupby_region.corr(method='pearson')
# Out:
#                  Country Score  Happiness Rank  Happiness Score
# Country Score         1.000000       -0.756549         0.750101
# Happiness Rank       -0.756549        1.000000        -0.996683
# Happiness Score       0.750101       -0.996683         1.000000
